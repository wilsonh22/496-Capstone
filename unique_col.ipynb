# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data.csv')
# Out:
# C:\Users\wilso\AppData\Local\Temp\ipykernel_36636\4160378179.py:4: DtypeWarning: Columns (0: sector, 1: goal_raw, 2: phase_raw, 3: id, 4: description) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   source_project_id                                         name  \
# 0         42392-013         Interisland Shipping Support Project
# 1         42439-013               Koror-Airai Sanitation Project
# 2         43197-013  Port Moresby Power Grid Development Project
# 3         46346-002    Ebeye Water Supply and Sanitation Project
# 4         46436-002           Samoa AgriBusiness Support Project
#
#    funding_amount       country_raw           start_date  \
# 0      29950000.0           Vanuatu  2011-11-30 00:00:00
# 1      28800000.0             Palau  2013-11-19 00:00:00
# 2      66700000.0  Papua New Guinea  2013-04-26 00:00:00
# 3       8000000.0  Marshall Islands  2015-09-28 00:00:00
# 4       5000000.0             Samoa  2014-06-17 00:00:00
#
#                                   recipient_name  \
# 0      Ministry of Finance & Economic Management
# 1                            Ministry of Finance
# 2  Independent Public Business Corporation(IPBC)
# ...

# %%
# source project id
# name
# country raw
# funder name?
df["unique_id"] = range(1, len(df) + 1)
